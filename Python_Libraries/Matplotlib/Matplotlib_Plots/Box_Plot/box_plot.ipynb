# %%
import matplotlib.pyplot as plt

marks = [45, 50, 52, 55, 60, 62, 65, 68, 70, 72,
         75, 78, 80, 82, 85, 90, 95, 98]

plt.boxplot(marks)

plt.title("Student Marks Distribution")
plt.ylabel("Marks")

plt.show()
