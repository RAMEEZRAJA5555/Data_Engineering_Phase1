# %%
#groupby() is used to group rows that have the same value, so you can then perform calculations on each group.
#Here we want to answer questions such as:

#What is the average salary in each city?

# %%
import pandas as pd

data = {
    "Name": ["Ali", "Sara", "Ahmed", "Hina", "Usman", "Ayesha", "Bilal", "Zara"],
    "Department": ["IT", "HR", "IT", "HR", "IT", "Finance", "Finance", "IT"],
    "City": ["Multan", "Lahore", "Karachi", "Lahore", "Multan", "Islamabad", "Multan", "Lahore"],
    "Salary": [50000, 60000, 45000, 70000, 55000, 65000, 48000, 75000]
}

df = pd.DataFrame(data)
print(df)

print(df.info())

#Average salary by city
#here in city col there are many same values so we will create group for this and we will so calculation on each group
#if values are not same,then groupby will still work,then each value will become their own group
print(df.groupby("City")["Salary"].mean())

#Total salary by city
print(df.groupby("City")["Salary"].sum())

#Number of employees in each city
print(df.groupby("City")["Name"].count())

#Minimum salary by city
print(df.groupby("City")["Salary"].min())

#Maximum salary by city
print(df.groupby("City")["Salary"].min())

#Average salary by department
print(df.groupby("Department")["Salary"].mean())
# Out:
#      Name Department       City  Salary
# 0     Ali         IT     Multan   50000
# 1    Sara         HR     Lahore   60000
# 2   Ahmed         IT    Karachi   45000
# 3    Hina         HR     Lahore   70000
# 4   Usman         IT     Multan   55000
# 5  Ayesha    Finance  Islamabad   65000
# 6   Bilal    Finance     Multan   48000
# 7    Zara         IT     Lahore   75000
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        8 non-null      str
#  1   Department  8 non-null      str
#  2   City        8 non-null      str
#  3   Salary      8 non-null      int64
# dtypes: int64(1), str(3)
# memory usage: 388.0 bytes
# None
# City
# Islamabad    65000.000000
# Karachi      45000.000000
# Lahore       68333.333333
# Multan       51000.000000
# Name: Salary, dtype: float64
# City
# Islamabad     65000
# Karachi       45000
# Lahore       205000
# ...

# %%
#groupby with agg():

#.agg() with single function:

#.agg() can be used to apply one aggregation function to grouped data.

"""
df.groupby("Department")["Salary"].agg("mean")
It calculates the mean salary for each department.

"""

# %%
#.agg() — Multiple functions

#.agg() can apply multiple aggregation functions to grouped data at the same time.

"""
df.groupby("Department")["Salary"].agg(["mean", "max", "min"])

It calculates the mean, maximum, and minimum salary for each department.

"""

# %%
#.transform()

#.transform() performs a calculation for each group and returns the result back to the original rows.

"""
df["Department_Avg"] = (
    df.groupby("Department")["Salary"].transform("mean")
)

Each employee gets the average salary of their own department.

"""

# %%
import pandas as pd

df = pd.DataFrame({
    "Name": ["Ali", "Sara", "Ahmed", "Hina", "Usman", "Ayesha"],
    "Department": ["IT", "IT", "HR", "HR", "Finance", "Finance"],
    "Salary": [80000, 100000, 60000, 70000, 90000, 110000]
})

print(df)

#it means For each department, calculate the average salary.
result1=df.groupby("Department")["Salary"].agg("mean")
print(result1)

#df.groupby("Department")["Salary"].mean()


#.agg() with multiple functions

result2 = df.groupby("Department")["Salary"].agg(
    ["mean", "max", "min"]
)

print(result2)

"""
You can also give the results your own names

result = df.groupby("Department").agg(
    average_salary=("Salary", "mean"),
    highest_salary=("Salary", "max"),
    lowest_salary=("Salary", "min")
)

print(result)
"""

#.transform()

#We want to add a new column showing the average salary of that employee's department.

df["Department_Avg"] = (
    df.groupby("Department")["Salary"].transform("mean")
)
print(df["Department_Avg"])

print(df)
# Out:
#      Name Department  Salary
# 0     Ali         IT   80000
# 1    Sara         IT  100000
# 2   Ahmed         HR   60000
# 3    Hina         HR   70000
# 4   Usman    Finance   90000
# 5  Ayesha    Finance  110000
# Department
# Finance    100000.0
# HR          65000.0
# IT          90000.0
# Name: Salary, dtype: float64
#                 mean     max    min
# Department
# Finance     100000.0  110000  90000
# HR           65000.0   70000  60000
# IT           90000.0  100000  80000
# 0     90000.0
# 1     90000.0
# 2     65000.0
# 3     65000.0
# 4    100000.0
# 5    100000.0
# Name: Department_Avg, dtype: float64
#      Name Department  Salary  Department_Avg
# 0     Ali         IT   80000         90000.0
# 1    Sara         IT  100000         90000.0
# 2   Ahmed         HR   60000         65000.0
# 3    Hina         HR   70000         65000.0
# 4   Usman    Finance   90000        100000.0
# 5  Ayesha    Finance  110000        100000.0
